# %% [markdown]
# # Part 3d: Food access in Ward 8
# ## What can you reach in 15 minutes in Ward 8 of DC?
#
# We are going to repeat the processes of Part 3b and 3c, but this time for Ward 8. We will use the information from the notebook, "vehicle_access_clean" where we found a variety of areas that are more than 10 minutes walking from a grocery store and have over 50% of households lacking vehicle access. We found the centroids of the polygons where these areas overlap and will use the following point randomly pulled from the list.
#
# 88     POINT (-77.00306 38.83097)
#
# ## Ward 8 Isochrone Map
#
# Taking this point, let's recreate the isochrone map for Ward 8. Note that because of the overwhelming complexity of the function that we would need to generate to create multiple isochrone maps, we've opted to copy over the information from the Ward 2 Isochrone map and change the point used for longitude and latitude. All other code is the same.

# %%
# import data
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
import networkx as nx
import contextily as ctx
import plotly.express as px
import osmnx as ox

# %% [markdown]
# Setting the parameters to calculate travel times for walking distance.

# %%
latlon= [38.83097, -77.00306]
network_type = 'walk'
trip_times = [5,10,15]
meters_per_minute = 75

# %% [markdown]
# Creating the graph variable to pull nodes and edges from.

# %%
G = ox.graph_from_point(latlon, network_type=network_type, dist = 2000)

# %% [markdown]
# Convert to a distance based coordinate system (EPSG:3857)

# %%
G = ox.project_graph(G, to_crs='epsg:3857')

# %% [markdown]
# Adding the edges and nodes to use to calculate travel times.

# %%
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)

# %% [markdown]
# Let's find the boundaries of the min and max coordinates of the polygon to find the centroid.

# %%
minx, miny, maxx, maxy = gdf_nodes.geometry.total_bounds
print(minx)
print(miny)
print(maxx)
print(maxy)
# Out:
# -8573700.265546476
# 4694922.986168832
# -8569381.637033101
# 4700057.279106445

# %% [markdown]
# We'll calculate an average point that will become the centroid.

# %%
centroid_x = (maxx-minx)/2 + minx
centroid_y = (maxy-miny)/2 + miny
print(centroid_x)
print(centroid_y)
# Out:
# -8571540.951289788
# 4697490.132637639

# %% [markdown]
# Tying this centroid to the nearest node:

# %%
ward8_node = ox.distance.nearest_nodes(G,Y=centroid_y,X=centroid_x)
print('The id for the nearest node is ' + str(ward8_node))
# Out:
# The id for the nearest node is 1468856024

# %% [markdown]
# Let's calculate walk times around this node.

# %%
gdf_edges['walk_time'] = gdf_edges['length']/meters_per_minute

# %%
cmap = 'YlGn'

# %% [markdown]
# Just want to double check that trip times are 5, 10, and 15 minutes.

# %%
trip_times
# Out:
# [5, 10, 15]

# %% [markdown]
# Double checking what colors are being used for each:

# %%
iso_colors = ox.plot.get_colors(n=len(trip_times), 
                                cmap=cmap, 
                                start=0, 
                                return_hex=True)
print(trip_times)
print(iso_colors)
# Out:
# [5, 10, 15]
# ['#ffffe5', '#77c679', '#004529']

# %% [markdown]
# We want to invert these colors so that the dark green shows 5 minutes (#004529) while the lighter color reflects 15 minutes away.

# %%
new_colors=['#004529','#77c679','#ffffe5']
print(new_colors)
# Out:
# ['#004529', '#77c679', '#ffffe5']

# %% [markdown]
# Let's try to zip these now to pair the list of trip times with the assigned colors:

# %%
time_color = list(zip(trip_times, new_colors))
time_color
# Out:
# [(5, '#004529'), (10, '#77c679'), (15, '#ffffe5')]

# %%
time_color.reverse()
time_color
# Out:
# [(15, '#ffffe5'), (10, '#77c679'), (5, '#004529')]

# %% [markdown]
# We want to create a for loop that connects each node within a time frame to a certain color. We'll create an egograph of nodes within this distance and then update the data frame for gdf_nodes with an associated distance color.

# %%
for time, color in list(time_color):
  
    subgraph = nx.ego_graph(G, ward8_node, radius=time,distance='time')

    print('There are ' + str(len(subgraph.nodes())) + ' nodes within ' + str(time) + ' minutes ' + color)
    
    for node in subgraph.nodes():
        gdf_nodes.loc[node,'time'] = time
        gdf_nodes.loc[node,'color'] = color
# Out:
# There are 667 nodes within 15 minutes #ffffe5
# There are 211 nodes within 10 minutes #77c679
# There are 53 nodes within 5 minutes #004529

# %% [markdown]
# Let's add a gray color for nodes that are outside fo the 15 minute walk watershed.

# %%
gdf_nodes['color'].fillna('#cccccc', inplace=True)
gdf_nodes.sample(3)
# Out:
#                        y             x  street_count        lon        lat  \
# osmid
# 1506921121  4.699046e+06 -8.571917e+06             3 -77.002840  38.841867
# 50526120    4.695005e+06 -8.571628e+06             3 -77.000242  38.813593
# 9739754006  4.698278e+06 -8.572257e+06             3 -77.005896  38.836498
#
#            highway                          geometry  time    color
# osmid
# 1506921121     NaN  POINT (-8571916.938 4699045.566)   NaN  #cccccc
# 50526120       NaN  POINT (-8571627.730 4695005.434)   NaN  #cccccc
# 9739754006     NaN  POINT (-8572257.097 4698278.315)   NaN  #cccccc

# %% [markdown]
# Let's plot the nodes to see what we get.

# %%
gdf_nodes.plot(figsize=(10,10),
               color=gdf_nodes['color'],
               markersize=3,
               )
# Out:
# <AxesSubplot: >

# %% [markdown]
# Creating a sample of nodes within 5 minutes walking distance.

# %%
gdf_5 = gdf_nodes[gdf_nodes['time']==5]

# %% [markdown]
# Let's plot it and see what points are formed...

# %%
gdf_5.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# Let's see the shape that's created from these nodes using Convex Hull.

# %%
gdf_5.unary_union.convex_hull
# Out:
# <POLYGON ((-8571433.611 4697361.006, -8571664.811 4697361.921, -8571826.213 ...>

# %% [markdown]
# Well....that's something. Let's hope the other shapes provide more insight into what's going on around this Safeway. We'll use dissolve for this next part to create polygons around the 5, 10, and 15 minute nodes.

# %%
isochrones = gdf_nodes.dissolve(by = "time")
isochrones
# Out:
#                                                geometry             y  \
# time
# 5.0   MULTIPOINT (-8571994.639 4697487.558, -8571826...  4.697488e+06
# 10.0  MULTIPOINT (-8572463.851 4697550.377, -8572455...  4.697550e+06
# 15.0  MULTIPOINT (-8573069.006 4695913.529, -8573001...  4.697763e+06
#
#                  x  street_count        lon        lat          highway  \
# time
# 5.0  -8.571995e+06             4 -77.003538  38.830965  traffic_signals
# 10.0 -8.572464e+06             4 -77.007753  38.831404  traffic_signals
# 15.0 -8.572533e+06             3 -77.008374  38.832895  traffic_signals
#
#         color
# time
# 5.0   #004529
# 10.0  #77c679
# 15.0  #ffffe5

# %% [markdown]
# We'll convert each row into a convex hull now using the geometry of the multiple nodes.

# %%
isochrones = isochrones.convex_hull.reset_index(name='geometry')
isochrones
# Out:
#    time                                           geometry
# 0   5.0  POLYGON ((-8571433.611 4697361.006, -8571664.8...
# 1  10.0  POLYGON ((-8572047.282 4696333.358, -8572073.2...
# 2  15.0  POLYGON ((-8572663.970 4695819.573, -8573069.0...

# %% [markdown]
# Now, we'll reverse the order so the 15 minute polygon is mapped first.

# %%
isochrones.sort_values(by='time', ascending=False,inplace=True)
isochrones
# Out:
#    time                                           geometry
# 2  15.0  POLYGON ((-8572663.970 4695819.573, -8573069.0...
# 1  10.0  POLYGON ((-8572047.282 4696333.358, -8572073.2...
# 0   5.0  POLYGON ((-8571433.611 4697361.006, -8571664.8...

# %% [markdown]
# Time to plot it and see what is produces!

# %%
isochrones.plot(figsize=(10,10),alpha=1,color=new_colors, legend=True)
# Out:
# <AxesSubplot: >

# %%
# set up the subplots
fig, ax = plt.subplots(figsize=(10,15))

# add the isochrone boundary
isochrones.boundary.plot(
    ax=ax,
    alpha=1,
    linestyle='--',
    color=new_colors,
    lw=2
    ) 

# add the isochrones
isochrones.plot(
    ax=ax, 
    alpha=0.2, 
    categorical=True, # even though it is numeric, treat it as categorical
    color=new_colors,
    )

# add the center node in red
gdf_nodes.loc[[ward8_node]].plot(ax=ax,color='r',marker='x',markersize=50)

# hide the axis
ax.axis('off')

# add the basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# ## Adding in Food Environment Markers to Maps
#
# Now, we'll quickly bring in the data for grocery stores, farmers markets, fast food, liquor licenses, and community gardens to plot them as markers within the isochrone map.
#
# Let's start with grocery stores...

# %%
grocery = pd.read_csv('Grocery_Store_Locations.csv')

# %% [markdown]
# Don't need to clean up everything because we know that we just need the coordinates in order to map everything. We'll turn it into a geodata frame now.

# %%
gdf_grocery = gpd.GeoDataFrame(grocery, 
                       crs='epsg:3857',
                       geometry=gpd.points_from_xy(grocery.X, grocery.Y))

# %%
gdf_grocery.head(2)
# Out:
#            X          Y                       STORENAME  \
# 0 -77.026981  38.984455                         Target
# 1 -77.026066  38.983464  International Progresso Market
#
#                   ADDRESS  ZIPCODE       PHONE    WARD           SSL NOTES  \
# 0  7828 GEORGIA AVENUE NW    20012  2028923822  Ward 4  2960    0017   NaN
# 1  7719 GEORGIA AVENUE NW    20012  2025455015  Ward 4  2961    0810   NaN
#
#   PRESENT90  ...     YCOORD  MAR_ID SE_ANNO_CAD_DATA  \
# 0       NaN  ...  146280.07  300512              NaN
# 1       NaN  ...  146169.97  285417              NaN
#
#                                  GLOBALID CREATOR                 CREATED  \
# 0  {CE302122-4E8D-4DC7-845B-06563B993F66}    JLAY  2022/09/28 18:04:54+00
# 1  {2C18863D-40DE-4F66-AA59-46F1C65D67F2}    JLAY  2022/09/28 18:04:54+00
#
#   EDITOR                  EDITED PRESENT22                geometry
# 0   JLAY  2022/09/28 18:04:54+00       Yes  POINT (-77.027 38.984)
# 1   JLAY  2022/09/28 18:04:54+00       Yes  POINT (-77.026 38.983)
#
# [2 rows x 37 columns]

# %% [markdown]
# Repeating the process of bringing in farmers markets and turning it into a geodata frame:

# %%
farmers = pd.read_csv('Farmers_Market_Locations.csv')

# %%
gdf_farmers=gpd.GeoDataFrame(farmers, 
                       crs='epsg:3857',
                       geometry=gpd.points_from_xy(farmers.X, farmers.Y))

# %%
gdf_farmers.head(2)
# Out:
#            X          Y                                      NAME  \
# 0 -77.075111  38.965166  Chevy Chase/Broad Branch Farmers' Market
# 1 -77.033134  38.955829            14th & Kennedy Farmers' Market
#
#             LAYER                  THEME IMAGE_                   ADDRESS  \
# 0  Farmers Market  Local Business & Food    NaN  5601 Connecticut Ave. NW
# 1  Farmers Market  Local Business & Food    NaN           5425 14th St NW
#
#   PHONE                                           VOUCHERS  PRIORITY_LEVEL  \
# 0   NaN                                                NaN             NaN
# 1   NaN  Accepts SNAP, WIC and senior farmers market nu...             NaN
#
#    ... SE_ANNO_CAD_DATA              GIS_ID  \
# 0  ...              NaN   FarmersMarketPt_9
# 1  ...              NaN  FarmersMarketPt_10
#
#                                  GLOBALID CREATOR CREATED EDITOR  \
# 0  {BA7F2149-421B-4053-9C2F-25BD6C2062D6}     NaN     NaN  DCGIS
# 1  {81DB3732-F194-4E23-BD85-4C01FFBA5870}     NaN     NaN  DCGIS
#
#                    EDITED   LATITUDE  LONGITUDE                geometry
# 0  2018/01/03 16:47:52+00  38.965159 -77.075109  POINT (-77.075 38.965)
# 1  2018/01/03 16:47:52+00  38.955822 -77.033132  POINT (-77.033 38.956)
#
# [2 rows x 34 columns]

# %% [markdown]
# Let's repeat the importing and converting into a geodataframe process for fast food:

# %%
fast = pd.read_csv('Fast Food Data.csv')

# %%
fast.rename(columns={'Geometry':'geometry'}, inplace=True)
fast.rename(columns={'Store Name':'NAME'}, inplace=True)

# %% [markdown]
# Time to convert it into a geodata frame.

# %%
gdf_fast = gpd.GeoDataFrame(fast, 
                       crs='epsg:3857',
                       geometry=gpd.points_from_xy(fast.Longitude, fast.Latitude))

# %%
gdf_fast.head(2)
# Out:
#         NAME Store Type                geometry   Latitude  Longitude  \
# 0  McDonalds  fast food  POINT (-77.077 38.945)  38.944559 -77.077161
# 1  McDonalds  fast food  POINT (-77.026 38.983)  38.982652 -77.025704
#
#                                        Address
# 0  4130 Wisconsin Ave NW, Washington, DC 20016
# 1    7425 Georgia Ave NW, Washington, DC 20011

# %% [markdown]
# We want to distinguish between "healthy" and "unhealthy" fast food so let us go ahead and create two separate variables for that.

# %%
fast_unhealthy=gdf_fast[gdf_fast['Store Type']=='fast food']
fast_healthy=gdf_fast[gdf_fast['Store Type']=='healthy fast food']

# %% [markdown]
# Repeat for liquor licenses:

# %%
liquor= pd.read_csv('Liquor_Licenses.csv')

# %%
gdf_liquor=gpd.GeoDataFrame(liquor, 
                       crs='epsg:3857',
                       geometry=gpd.points_from_xy(liquor.X, liquor.Y))

# %%
gdf_liquor.head(2)
# Out:
#            X          Y      LICENSE                          APPLICANT  \
# 0 -77.031549  38.897027  ABRA-000001  National Press Club of Washington
# 1 -77.083582  38.957499  ABRA-000010                 Pauls Liquors Inc.
#
#                      TRADE_NAME CLASS                   ADDRESS  ZIPCODE  \
# 0           National Press Club     C        529 14TH STREET NW    20045
# 1  Pauls Discount Wine & Liquor     A  5205 WISCONSIN AVENUE NW    20015
#
#      WARD     ANC  ...  LONGITUDE   LATITUDE            GIS_ID  \
# 0  Ward 2  ANC 2C  ... -77.031547  38.897019  ABRALicenseePt_1
# 1  Ward 3  ANC 3E  ... -77.083579  38.957492  ABRALicenseePt_2
#
#                                  GLOBALID CREATOR                 CREATED  \
# 0  {36A31358-161C-4533-A08E-FC5306477588}    JLAY  2022/08/31 18:04:53+00
# 1  {46323846-6F1F-4459-A270-C3D9AF62CB07}    JLAY  2022/08/31 18:04:53+00
#
#   EDITOR                  EDITED OBJECTID                geometry
# 0   JLAY  2022/08/31 18:04:53+00     4801  POINT (-77.032 38.897)
# 1   JLAY  2022/08/31 18:04:53+00     4802  POINT (-77.084 38.957)
#
# [2 rows x 42 columns]

# %% [markdown]
# We only want to display Class A liquor licenses, which are retailers (not in grocery stores). Let's make that a separate variable.

# %%
liquor_stores=gdf_liquor[gdf_liquor['CLASS']=='A']

# %% [markdown]
# Now, moving onto community gardens:

# %%
garden=pd.read_csv('Community_Gardens.csv')

# %%
garden.head(2)
# Out:
#            X          Y  OBJECTID                   ADDRESS  \
# 0 -77.030970  38.970534         1  1327 VAN BUREN STREET NW
# 1 -77.018054  38.968894         2   300 VAN BUREN STREET NW
#
#                  NAME  PLOTS ORGANIZATION     XCOORD     YCOORD    MAR_ID  \
# 0  Ft. Stevens Garden    9.0          DPR  397305.72  144706.25  290152.0
# 1       Takoma Garden   11.0          DPR  398435.64  144552.48  296168.0
#
#    ...                                       WEB_URL COMMENTS   LATITUDE  \
# 0  ...  http://dpr.dc.gov/page/dpr-community-gardens           38.970527
# 1  ...                                           NaN      NaN  38.968887
#
#    LONGITUDE               GIS_ID                                GLOBALID  \
# 0 -77.030967  CommunityGardenPt_1  {D424973D-2F1D-4E71-A332-569D43EB7F8D}
# 1 -77.018052  CommunityGardenPt_2  {3F59A195-CC57-4949-A6B5-A7DDCF90E34A}
#
#    CREATOR  CREATED EDITOR EDITED
# 0      NaN      NaN    NaN    NaN
# 1      NaN      NaN    NaN    NaN
#
# [2 rows x 24 columns]

# %%
gdf_garden=gpd.GeoDataFrame(garden, 
                       crs='epsg:3857',
                       geometry=gpd.points_from_xy(garden.X, garden.Y))

# %%
gdf_garden.head(2)
# Out:
#            X          Y  OBJECTID                   ADDRESS  \
# 0 -77.030970  38.970534         1  1327 VAN BUREN STREET NW
# 1 -77.018054  38.968894         2   300 VAN BUREN STREET NW
#
#                  NAME  PLOTS ORGANIZATION     XCOORD     YCOORD    MAR_ID  \
# 0  Ft. Stevens Garden    9.0          DPR  397305.72  144706.25  290152.0
# 1       Takoma Garden   11.0          DPR  398435.64  144552.48  296168.0
#
#    ... COMMENTS   LATITUDE  LONGITUDE               GIS_ID  \
# 0  ...           38.970527 -77.030967  CommunityGardenPt_1
# 1  ...      NaN  38.968887 -77.018052  CommunityGardenPt_2
#
#                                  GLOBALID CREATOR  CREATED  EDITOR EDITED  \
# 0  {D424973D-2F1D-4E71-A332-569D43EB7F8D}     NaN      NaN     NaN    NaN
# 1  {3F59A195-CC57-4949-A6B5-A7DDCF90E34A}     NaN      NaN     NaN    NaN
#
#                  geometry
# 0  POINT (-77.031 38.971)
# 1  POINT (-77.018 38.969)
#
# [2 rows x 25 columns]

# %% [markdown]
# ## Adding Food Environment to the Isochrone Maps
#
# Now that we have these geodata frames ready to go, let's add them to an interactive folium map!

# %%
m = folium.Map(location=latlon,zoom_start=15, tiles='Stamen Terrain')

m = folium.Map(location=[38.83097, -77.00306],
               zoom_start = 20,
               tiles='CartoDB positron', 
               attribution='CartoDB')

isochrones.explore(m=m,name="Walking Distances around Central Point",column='time',cmap=cmap,categorical=True)


m2=folium.FeatureGroup(name= "Grocery Stores").add_to(m)
for index, row in gdf_grocery.iterrows():
    folium.Marker([row.Y, row.X], popup=row.STORENAME, tooltip=row.STORENAME, icon=folium.Icon(color='green',icon_color='white', icon='shopping-cart')).add_to(m2)

m3=folium.FeatureGroup(name= "Farmers Markets").add_to(m)
for index, row in gdf_farmers.iterrows():
    folium.Marker([row.Y, row.X], popup=row.NAME, tooltip=row.NAME, icon=folium.Icon(color='green', icon_color='white', icon='leaf')).add_to(m3)

m4=folium.FeatureGroup(name= "Community Gardens").add_to(m)
for index, row in gdf_garden.iterrows():
    folium.Marker([row.Y, row.X], popup=row.NAME, tooltip=row.NAME, icon=folium.Icon(color='green', icon='tree-deciduous')).add_to(m4)

m5=folium.FeatureGroup(name= "Healthy Fast Food").add_to(m)
for index, row in fast_healthy.iterrows():
    folium.Marker([row.Latitude, row.Longitude], popup=row.NAME, tooltip=row.NAME, icon=folium.Icon(color='green', icon='cutlery')).add_to(m5)
    
m6=folium.FeatureGroup(name= "Unhealthy Fast Food").add_to(m)
for index, row in fast_unhealthy.iterrows():
    folium.Marker([row.Latitude, row.Longitude], popup=row.NAME, tooltip=row.NAME, icon=folium.Icon(color='black', icon='cutlery')).add_to(m6)
    
m7=folium.FeatureGroup(name= "Liquor License").add_to(m)
for index, row in liquor_stores.iterrows():
    folium.Marker([row.Y, row.X], popup=row.TRADE_NAME, tooltip=row.TRADE_NAME, icon=folium.Icon(color='black', icon='glass')).add_to(m7)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3866bcc74dc73cb0f1b4d7389f21894 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend time&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;time&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ffffe5&#x27;&gt;&lt;/span&gt;5.0&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#78c679&#x27;&gt;&lt;/span&gt;10.0&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#004529&#x27;&gt;&lt;/span&gt;15.0&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3866bcc74dc73cb0f1b4d7389f21894&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3866bcc74dc73cb0f1b4d7389f21894 = L.map(
#                 &quot;map_b3866bcc74dc73cb0f1b4d7389f21894&quot;,
#                 {
#                     center: [38.83097, -77.00306],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     attribution: &quot;CartoDB&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02aa4921378a4b81a3629823b7d07568 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b3866bcc74dc73cb0f1b4d7389f21894);
#
#
#         function geo_json_013f73f538d855e909b9ae9dd141dfb3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#004529&quot;, &quot;fillColor&quot;: &quot;#004529&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#78c679&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#ffffe5&quot;, &quot;fillColor&quot;: &quot;#ffffe5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_013f73f538d855e909b9ae9dd141dfb3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_013f73f538d855e909b9ae9dd141dfb3_pointToLayer(feat

# %% [markdown]
# What's interesting to see in this food desert is the stronger presence of farmers markets and community gardens. Again, there is a higher concentration of liquor stores than any other type of food resource, with 7 within walking distance. Yet, there are 3 farmer's markets, all of which are Arcadia's Mobile Markets, and the Ferebee Hope Community Garden as key food resources.

# %%
m.save('Ward8isochronemap.html')
